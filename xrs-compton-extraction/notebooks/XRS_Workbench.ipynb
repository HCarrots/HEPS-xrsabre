# %% [markdown]
# # XRS Compton Extraction Workbench
#
# This notebook contains only the user-interface entry point. Scientific algorithms live in the installable `xrs_compton_extraction` package.

# %%
from xrs_compton_extraction import XRSWorkbench

app = XRSWorkbench()
app.display()
